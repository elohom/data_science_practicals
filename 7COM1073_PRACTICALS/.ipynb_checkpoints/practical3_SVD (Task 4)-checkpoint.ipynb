# %%
import numpy as np
import matplotlib.pyplot as plt
#used to import the numpy library

# %%
#Used to install the library package if not on the machine used to run the python code
# !pip install scikit=image
# Out:
# ERROR: Invalid requirement: 'scikit=image'
# Hint: = is not a valid operator. Did you mean == ?

# %%
from skimage import data
from skimage.color import rgb2gray

# used to convert the image into gray scale image

from skimage import img_as_ubyte,img_as_float

# Used to save an image into unsigned bits or changing the type of the data into a float

cat_image = rgb2gray(img_as_float(data.chelsea()))  
plt.imshow(cat_image, cmap='gray')

# %%
from numpy.linalg import svd

# %%
original_shape = cat_image.shape
print(original_shape)
# Out:
# (300, 451)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def compress_svd(image,k):
    """
    Perform svd decomposition and truncated (using k singular values/vectors) reconstruction
    returns
    --------
      reconstructed matrix reconst_matrix, array of singular values s
    """
    U,s,V = svd(image,full_matrices=False)
    reconst_matrix = np.dot(U[:,??],np.dot(np.diag(s[??]),V[??,:]))
   
    return reconst_matrix,s
# Out:
#   Input In [6]
#     reconst_matrix = np.dot(U[:,??],np.dot(np.diag(s[??]),V[??,:]))
#                                 ^
# SyntaxError: invalid syntax
